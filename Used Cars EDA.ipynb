# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# #### Importing standard libraries

# %%
import pymongo
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from pymongo import MongoClient
db_client = MongoClient()

# %% [markdown]
# #### Connecting to database and fetching data

# %%
data = pd.DataFrame(list(db_client.web_scraping_db.cars.find()))

# %%
data
# Out:
#                           _id                                      Listing  \
# 0    5ed31494057e58cb9502f23a  Mercedes CLA ð¯ Accident Free â¤ï¸ 2014
# 1    5ed31497057e58cb9502f23b       Mercedes Cclass leather Seat trim 2003
# 2    5ed3149a057e58cb9502f23c                          Suzuki Forenza 2006
# 3    5ed3149c057e58cb9502f23d                    Toyota Venza Limited 2011
# 4    5ed3149f057e58cb9502f23e                   Toyota Highlander XLE 2015
# ..                        ...                                          ...
# 761  5ed31ef6057e58cb9502f54f                             Kia Morning 2010
# 762  5ed31efa057e58cb9502f550                         Toyota Camry SE 2012
# 763  5ed31efe057e58cb9502f551                   Range Rover Sport HSE 2014
# 764  5ed31f02057e58cb9502f552             Peugeot 305 New Type Estate 1998
# 765  5ed31f04057e58cb9502f553               Hyundai Elantra Auto 1.8L 2012
#
#              Price Condition:       Brand:       Model:   \
# 0    GHâµ 120,000         New     Mercedes          CLA
# 1     GHâµ 37,000        Used     Mercedes       Cclass
# 2     GHâµ 18,000        Used       Suzuki  Other Model
# 3     GHâµ 75,000        Used       Toyota        Venza
# 4    GHâµ 158,000        Used       Toyota   Highlander
# ..             ...         ...          ...          ...
# 761   GHâµ 26,000         New          Kia      Morning
# 762   GHâµ 68,000         New       Toyota        Camry
# 763  GHâµ 270,000        Used  Range Rover        Sport
# 764    GHâµ 4,500        Used      Peugeot  Other Model
# 765   GHâµ 31,000        Used      Hyundai      Elantra
#
#               Trim / Edition:  Model year:  Transmission:  Body type:   \
# 0    ð¯ Accident Free â¤ï¸         2014      Automatic      Saloon
# 1            leather Seat trim         2003         Manual      Saloon
# 2                      Forenza         2006      Automatic      Saloon
# 3                      Limited         2011      Automatic   SUV / 4x4
# 4                          XLE         2015      Automatic   SUV / 4x4
# ..                         ...          ...            ...         ...
# 761                    Morning         2010      Automatic   Hatchback
# 762                         SE         2012      Automatic      Saloon
# 763                        HSE         2014      Automatic   SUV / 4x4
# 764        305 New Type Estate         1998         Manual      Estate
# 765                  Auto 1.8L         2012      Automatic      Saloon
#
#     Fuel type:    Mileage:  Engine capacity:
# 0        Petrol   80,000 km         2.0 Liter
# 1        Petrol        0 km         1.8 Liter
# 2        Petrol   61,000 km         2.0 Liter
# 3        Petrol   68,500 km         3.5 Liter
# 4        Petrol   38,000 km         3.5 Liter
# ..          ...         ...               ...
# 761      Petrol   55,000 km         1.0 Liter
# 762      Petrol  100,000 km         2.4 Liter
# 763      Petrol   17,512 km         3.0 Liter
# 764      Petrol    9,881 km         2.0 Liter
# 765      Petrol   42,362 km         1.8 Liter
#
# [766 rows x 13 columns]

# %% [markdown]
# ## Cleaning the data

# %% [markdown]
# #### Changing column headers

# %%
data.isnull().sum()
# Out:
# _id                    0
# Listing                0
# Price                  0
# Condition:             0
# Brand:                 0
# Model:                 0
# Trim / Edition:      249
# Model year:            0
# Transmission:          0
# Body type:            29
# Fuel type:             0
# Mileage:               0
# Engine capacity:       0
# dtype: int64

# %%
data.rename(columns={'Condition: ':'Condition', 'Brand: ':'Brand', 'Model: ':'Model', 'Trim/Edition: ':'Trim/Edition', 'Model year: ':'Model year', 'Transmission: ':'Transmission','Body type: ':'Body type', 'Fuel type: ':'Fuel type','Mileage: ':'Mileage', 'Engine capacity: ':'Engine capacity'}, inplace=True)

# %%
data.columns
# Out:
# Index(['_id', 'Listing', 'Price', 'Condition', 'Brand', 'Model',
#        'Trim / Edition: ', 'Model year', 'Transmission', 'Body type',
#        'Fuel type', 'Mileage', 'Engine capacity'],
#       dtype='object')

# %% [markdown]
# #### Drop _id column

# %%
data.drop(columns=['_id', 'Trim / Edition: '], inplace=True)

# %%
data
# Out:
#                                          Listing          Price Condition  \
# 0    Mercedes CLA ð¯ Accident Free â¤ï¸ 2014  GHâµ 120,000       New
# 1         Mercedes Cclass leather Seat trim 2003   GHâµ 37,000      Used
# 2                            Suzuki Forenza 2006   GHâµ 18,000      Used
# 3                      Toyota Venza Limited 2011   GHâµ 75,000      Used
# 4                     Toyota Highlander XLE 2015  GHâµ 158,000      Used
# ..                                           ...            ...       ...
# 761                             Kia Morning 2010   GHâµ 26,000       New
# 762                         Toyota Camry SE 2012   GHâµ 68,000       New
# 763                   Range Rover Sport HSE 2014  GHâµ 270,000      Used
# 764             Peugeot 305 New Type Estate 1998    GHâµ 4,500      Used
# 765               Hyundai Elantra Auto 1.8L 2012   GHâµ 31,000      Used
#
#            Brand        Model Model year Transmission  Body type Fuel type  \
# 0       Mercedes          CLA       2014    Automatic     Saloon    Petrol
# 1       Mercedes       Cclass       2003       Manual     Saloon    Petrol
# 2         Suzuki  Other Model       2006    Automatic     Saloon    Petrol
# 3         Toyota        Venza       2011    Automatic  SUV / 4x4    Petrol
# 4         Toyota   Highlander       2015    Automatic  SUV / 4x4    Petrol
# ..           ...          ...        ...          ...        ...       ...
# 761          Kia      Morning       2010    Automatic  Hatchback    Petrol
# 762       Toyota        Camry       2012    Automatic     Saloon    Petrol
# 763  Range Rover        Sport       2014    Automatic  SUV / 4x4    Petrol
# 764      Peugeot  Other Model       1998       Manual     Estate    Petrol
# 765      Hyundai      Elantra       2012    Automatic     Saloon    Petrol
#
#         Mileage Engine capacity
# 0     80,000 km       2.0 Liter
# 1          0 km       1.8 Liter
# 2     61,000 km       2.0 Liter
# 3     68,500 km       3.5 Liter
# 4     38,000 km       3.5 Liter
# ..          ...             ...
# 761   55,000 km       1.0 Liter
# 762  100,000 km       2.4 Liter
# 763   17,512 km       3.0 Liter
# 764    9,881 km       2.0 Liter
# 765   42,362 km       1.8 Liter
#
# [766 rows x 11 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 766 entries, 0 to 765
# Data columns (total 11 columns):
# Listing            766 non-null object
# Price              766 non-null object
# Condition          766 non-null object
# Brand              766 non-null object
# Model              766 non-null object
# Model year         766 non-null object
# Transmission       766 non-null object
# Body type          737 non-null object
# Fuel type          766 non-null object
# Mileage            766 non-null object
# Engine capacity    766 non-null object
# dtypes: object(11)
# memory usage: 66.0+ KB

# %%
data.isna().sum()
# Out:
# Listing             0
# Price               0
# Condition           0
# Brand               0
# Model               0
# Model year          0
# Transmission        0
# Body type          29
# Fuel type           0
# Mileage             0
# Engine capacity     0
# dtype: int64

# %%
def get_price(price):
    return price.split(" ")[1]

def comma(price):
    return price.replace(",", "")

# %%
data['Price'] = data['Price'].apply(lambda x: get_price(x))

data['Price'] = data['Price'].apply(lambda x: comma(x))

# %%
data['Price'] = data['Price'].astype(int)

# %%
data.Price
# Out:
# 0      120000
# 1       37000
# 2       18000
# 3       75000
# 4      158000
#         ...
# 761     26000
# 762     68000
# 763    270000
# 764      4500
# 765     31000
# Name: Price, Length: 766, dtype: int32

# %%
def get_fig(mileage):
    return mileage.split(" ")[0]

# %%
data.Mileage = data.Mileage.apply(lambda x: get_fig(x))

data.Mileage = data.Mileage.apply(lambda x: comma(x))

# %%
data.Mileage = data.Mileage.astype(int)

# %%
data['Engine capacity'] = data['Engine capacity'].apply(lambda x: get_fig(x))

data['Engine capacity'] = data['Engine capacity'].astype(float)

# %%
data.rename(columns={"Mileage":"Mileage(KM)", "Engine capacity": "Engine capacity(LTR)", "Price":"Price(GH¢)"}, inplace=True)

# %%
data
# Out:
#                                          Listing  Price(GH¢) Condition  \
# 0    Mercedes CLA ð¯ Accident Free â¤ï¸ 2014      120000       New
# 1         Mercedes Cclass leather Seat trim 2003       37000      Used
# 2                            Suzuki Forenza 2006       18000      Used
# 3                      Toyota Venza Limited 2011       75000      Used
# 4                     Toyota Highlander XLE 2015      158000      Used
# ..                                           ...         ...       ...
# 761                             Kia Morning 2010       26000       New
# 762                         Toyota Camry SE 2012       68000       New
# 763                   Range Rover Sport HSE 2014      270000      Used
# 764             Peugeot 305 New Type Estate 1998        4500      Used
# 765               Hyundai Elantra Auto 1.8L 2012       31000      Used
#
#            Brand        Model Model year Transmission  Body type Fuel type  \
# 0       Mercedes          CLA       2014    Automatic     Saloon    Petrol
# 1       Mercedes       Cclass       2003       Manual     Saloon    Petrol
# 2         Suzuki  Other Model       2006    Automatic     Saloon    Petrol
# 3         Toyota        Venza       2011    Automatic  SUV / 4x4    Petrol
# 4         Toyota   Highlander       2015    Automatic  SUV / 4x4    Petrol
# ..           ...          ...        ...          ...        ...       ...
# 761          Kia      Morning       2010    Automatic  Hatchback    Petrol
# 762       Toyota        Camry       2012    Automatic     Saloon    Petrol
# 763  Range Rover        Sport       2014    Automatic  SUV / 4x4    Petrol
# 764      Peugeot  Other Model       1998       Manual     Estate    Petrol
# 765      Hyundai      Elantra       2012    Automatic     Saloon    Petrol
#
#      Mileage(KM)  Engine capacity(LTR)
# 0          80000                   2.0
# 1              0                   1.8
# 2          61000                   2.0
# 3          68500                   3.5
# 4          38000                   3.5
# ..           ...                   ...
# 761        55000                   1.0
# 762       100000                   2.4
# 763        17512                   3.0
# 764         9881                   2.0
# 765        42362                   1.8
#
# [766 rows x 11 columns]

# %%
data.agg({'Price(GH¢)': ['min', 'max', 'mean', 'median', 'skew'], 
          'Mileage(KM)':['min', 'max', 'mean', 'median', 'skew'], 
          'Engine capacity(LTR)':['min', 'max', 'mean', 'median', 'skew']})
# Out:
#            Price(GH¢)     Mileage(KM)  Engine capacity(LTR)
# min        250.000000        0.000000              0.700000
# max     595000.000000  1000000.000000              5.700000
# mean     61911.766319    75878.597911              2.058355
# median   39212.500000    63944.500000              1.800000
# skew         3.733296        6.242489              1.432553

# %%
median_mileage = data.groupby('Brand')['Mileage(KM)'].median()

# %%
data['Mileage(KM)']=data['Mileage(KM)'].mask(data['Mileage(KM)']==0).fillna(median_mileage)

# %%
data['Mileage(KM)']
# Out:
# 0       80000.0
# 1           NaN
# 2       61000.0
# 3       68500.0
# 4       38000.0
#          ...
# 761     55000.0
# 762    100000.0
# 763     17512.0
# 764      9881.0
# 765     42362.0
# Name: Mileage(KM), Length: 766, dtype: float64

# %%
data['Mileage(KM)'] = data['Mileage(KM)'].replace(0, median_mileage)

# %%
data['Mileage(KM)']
# Out:
# 0       80000
# 1           0
# 2       61000
# 3       68500
# 4       38000
#         ...
# 761     55000
# 762    100000
# 763     17512
# 764      9881
# 765     42362
# Name: Mileage(KM), Length: 766, dtype: int32
